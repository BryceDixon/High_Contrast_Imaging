# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
K_mag = [7.084,
7.276,
7.284,
7.39,
7.423,
7.35,
7.508,
7.701,
7.671,
7.748,
6.987,
7.14,
7.223,
7.163,
7.408,
7.337,
7.516,
7.321,
7.651,
7.808,
7.376,
7.507,
7.41,
7.792,
8.065,
8.267,
6.975,
7.345,
7.953,
7.392,
7.562,
7.245,
7.268,
7.452,
7.8]

fig = plt.figure(figsize = (7,7))
ax = fig.add_subplot(1,1,1)
ax.hist(K_mag, bins = [6.8, 7.0, 7.2, 7.4, 7.6, 7.8, 8.0, 8.2, 8.4], color = 'chocolate')
ax.xaxis.set_major_locator(plt.MaxNLocator(10))
ax.set_xlabel('K band Magnitude')
ax.set_ylabel('Target Star Frequency')
ax.set_title('Histogram showing the K band magnidues of the 35 Sco-Cen Target Stars')
# Out:
# Text(0.5, 1.0, 'Histogram showing the K band magnidues of the 35 Sco-Cen Target Stars')
