# %%
import numpy as np
import matplotlib.pyplot as plt
import astropy.io.fits as fits

# %%
fit = fits.open('C:/Users/bryce/Python/High Contrast Imaging Project/Year_4/science_case_Dec2020/cc_adi_bckg1_mag-0.63_L_CVC_fullM1_all_effects.fits')
fit.info()
# Out:
# Filename: C:/Users/bryce/Python/High Contrast Imaging Project/Year_4/science_case_Dec2020/cc_adi_bckg1_mag-0.63_L_CVC_fullM1_all_effects.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       6   (157, 2)   float32

# %%
data = fits.getdata('C:/Users/bryce/Python/High Contrast Imaging Project/Year_4/science_case_Dec2020/cc_adi_bckg1_mag-0.648_M_CVC_fullM1_all_effects.fits', ext=0)

x = data[0,:]
y = data[1,:]

plt.figure(figsize=(10,6))
plt.plot(x,y)
plt.yscale('log')
plt.xscale('log')
plt.grid()
plt.xlabel('Angular Seperation (arcsec)')
plt.ylabel('5-$\sigma$ Sensitivity (Contrast)')
plt.title('M-band, -0.648 mag, all efects')
# Out:
# Text(0.5, 1.0, 'M-band, -0.648 mag, all efects')
